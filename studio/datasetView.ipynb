# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("synthetic_dataset.csv")

# %%
df.head()
# Out:
#   Conference  Year                                              Title  \
# 0    InfoVis  2011                           D³ Data-Driven Documents
# 1    InfoVis  2014          UpSet: Visualization of Intersecting Sets
# 2    InfoVis  2010  Narrative Visualization: Telling Stories with ...
# 3    InfoVis  2006  Hierarchical Edge Bundles: Visualization of Ad...
# 4    InfoVis  2007  Toward a Deeper Understanding of the Role of I...
#
#                          DOI                                         Link  \
# 0      10.1109/tvcg.2011.185      http://dx.doi.org/10.1109/TVCG.2011.185
# 1  10.1109/tvcg.2014.2346248  http://dx.doi.org/10.1109/TVCG.2014.2346248
# 2      10.1109/tvcg.2010.179      http://dx.doi.org/10.1109/TVCG.2010.179
# 3      10.1109/tvcg.2006.147      http://dx.doi.org/10.1109/TVCG.2006.147
# 4    10.1109/tvcg.2007.70515    http://dx.doi.org/10.1109/TVCG.2007.70515
#
#    FirstPage  LastPage PaperType  \
# 0     2301.0    2309.0         J
# ...
